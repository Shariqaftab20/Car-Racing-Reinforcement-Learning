# %%
# !pip install gym[box2d] pyglet
# Out:
# Requirement already satisfied: gym[box2d] in c:\users\shari\anaconda3\lib\site-packages (0.26.2)
# Requirement already satisfied: pyglet in c:\users\shari\anaconda3\lib\site-packages (1.5.21)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\shari\anaconda3\lib\site-packages (from gym[box2d]) (4.11.3)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\users\shari\anaconda3\lib\site-packages (from gym[box2d]) (0.0.8)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\shari\anaconda3\lib\site-packages (from gym[box2d]) (1.24.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\shari\anaconda3\lib\site-packages (from gym[box2d]) (2.0.0)
# Requirement already satisfied: pygame==2.1.0 in c:\users\shari\anaconda3\lib\site-packages (from gym[box2d]) (2.1.0)
# Requirement already satisfied: swig==4.* in c:\users\shari\anaconda3\lib\site-packages (from gym[box2d]) (4.1.1)
# Requirement already satisfied: box2d-py==2.3.5 in c:\users\shari\anaconda3\lib\site-packages (from gym[box2d]) (2.3.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\shari\anaconda3\lib\site-packages (from importlib-metadata>=4.8.0->gym[box2d]) (3.8.0)

# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
environment_name = "CarRacing-v2"

# %%
log_path = os.path.join("Training","Logs")
log_path
# Out:
# 'Training\\Logs'

# %%
env = gym.make(environment_name,render_mode="human")
env = DummyVecEnv([lambda: env])
model = PPO('CnnPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=300000)
# Out:
# Logging to Training\Logs\PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 16   |
# |    iterations      | 1    |
# |    time_elapsed    | 121  |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 2            |
# |    time_elapsed         | 301          |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0052965023 |
# |    clip_fraction        | 0.0654       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | -0.0127      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.286        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00501     |
# |    std                  | 0.994        |
# |    value_loss           | 0.638        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 3          |
# |    time_elapsed         | 474        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00557287 |
# |    clip_fraction        | 0.0683     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.24      |
# |    explained_variance   | 0.124      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.294      |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00724   |
# |    std                  | 0.991      |
# |    value_loss           | 0.584      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 4           |
# |    time_elapsed         | 648         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009978209 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.114       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00979    |
# |    std                  | 0.98        |
# |    value_loss           | 0.44        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 5           |
# |    time_elapsed         | 817         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010651462 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.344       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.141       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 0.974       |
# |    value_loss           | 0.428       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 6           |
# |    time_elapsed         | 994         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012609392 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.292       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0668      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.974       |
# |    value_loss           | 0.316       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 7           |
# |    time_elapsed         | 1196        |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011084207 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.397       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.045       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.965       |
# |    value_loss           | 0.368       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 8           |
# |    time_elapsed         | 1402        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009438975 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.276       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.172       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.96        |
# |    value_loss           | 0.457       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 9          |
# |    time_elapsed         | 1602       |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01250823 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.11      |
# |    explained_variance   | 0.264      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.109      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0183    |
# |    std                  | 0.947      |
# |    value_loss           | 0.335      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 10          |
# |    time_elapsed         | 1791        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.015583655 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.408       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0692      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0169     |
# |    std                  | 0.929       |
# |    value_loss           | 0.432       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 11          |
# |    time_elapsed         | 1984        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.023224521 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.543       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.1         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0274     |
# |    std                  | 0.923       |
# |    value_loss           | 0.352       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 12          |
# |    time_elapsed         | 2172        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.022171462 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.114       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0267     |
# |    std                  | 0.912       |
# |    value_loss           | 0.299       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 13          |
# |    time_elapsed         | 2362        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.018945014 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.626       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0797      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0266     |
# |    std                  | 0.9         |
# |    value_loss           | 0.287       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 14          |
# |    time_elapsed         | 2550        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.020320678 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0761      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0269     |
# |    std                  | 0.887       |
# |    value_loss           | 0.406       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 15          |
# |    time_elapsed         | 2743        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.023333285 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.88       |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.126       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0284     |
# |    std                  | 0.879       |
# |    value_loss           | 0.375       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 16          |
# |    time_elapsed         | 2933        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.025243212 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.86       |
# |    explained_variance   | 0.764       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0315      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0283     |
# |    std                  | 0.874       |
# |    value_loss           | 0.324       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 17          |
# |    time_elapsed         | 3118        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.028242743 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.81       |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00285     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0309     |
# |    std                  | 0.854       |
# |    value_loss           | 0.223       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 18          |
# |    time_elapsed         | 3306        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.038111527 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.76       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0193      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0318     |
# |    std                  | 0.843       |
# |    value_loss           | 0.203       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 19         |
# |    time_elapsed         | 3500       |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.03208145 |
# |    clip_fraction        | 0.273      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.71      |
# |    explained_variance   | 0.867      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0291     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0354    |
# |    std                  | 0.828      |
# |    value_loss           | 0.386      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 20          |
# |    time_elapsed         | 3689        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.034173135 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0299      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0349     |
# |    std                  | 0.815       |
# |    value_loss           | 0.42        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 21          |
# |    time_elapsed         | 3884        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.041762322 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.62       |
# |    explained_variance   | 0.824       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0538      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0284     |
# |    std                  | 0.809       |
# |    value_loss           | 0.484       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 22          |
# |    time_elapsed         | 4073        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.040638097 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.175       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0361     |
# |    std                  | 0.802       |
# |    value_loss           | 0.744       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 23         |
# |    time_elapsed         | 4265       |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.03682467 |
# |    clip_fraction        | 0.322      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.57      |
# |    explained_variance   | 0.822      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0958     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0373    |
# |    std                  | 0.795      |
# |    value_loss           | 0.953      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 24          |
# |    time_elapsed         | 4458        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.054574803 |
# |    clip_fraction        | 0.346       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0546      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0369     |
# |    std                  | 0.787       |
# |    value_loss           | 0.779       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 25         |
# |    time_elapsed         | 4650       |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.03524085 |
# |    clip_fraction        | 0.313      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.51      |
# |    explained_variance   | 0.512      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.447      |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0285    |
# |    std                  | 0.784      |
# |    value_loss           | 1.22       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 26          |
# |    time_elapsed         | 4846        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.054574728 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.5        |
# |    explained_variance   | 0.571       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.189       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.042      |
# |    std                  | 0.779       |
# |    value_loss           | 0.816       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 27          |
# |    time_elapsed         | 5027        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.046225198 |
# |    clip_fraction        | 0.373       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.48       |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0413      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0335     |
# |    std                  | 0.778       |
# |    value_loss           | 1.25        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 28          |
# |    time_elapsed         | 5219        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.060724147 |
# |    clip_fraction        | 0.374       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.46       |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0964      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0424     |
# |    std                  | 0.766       |
# |    value_loss           | 0.95        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 29          |
# |    time_elapsed         | 5405        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.056100123 |
# |    clip_fraction        | 0.386       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.42       |
# |    explained_variance   | 0.424       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.121       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0363     |
# |    std                  | 0.76        |
# |    value_loss           | 1.12        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 30         |
# |    time_elapsed         | 5589       |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.07047568 |
# |    clip_fraction        | 0.401      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.39      |
# |    explained_variance   | 0.864      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.103      |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.039     |
# |    std                  | 0.749      |
# |    value_loss           | 0.92       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 31          |
# |    time_elapsed         | 5779        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.050411843 |
# |    clip_fraction        | 0.352       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.35       |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.145       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0395     |
# |    std                  | 0.743       |
# |    value_loss           | 1.42        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 32         |
# |    time_elapsed         | 5970       |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.05384263 |
# |    clip_fraction        | 0.358      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.31      |
# |    explained_variance   | 0.474      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.359      |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0289    |
# |    std                  | 0.734      |
# |    value_loss           | 1.61       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 33         |
# |    time_elapsed         | 6154       |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.06803447 |
# |    clip_fraction        | 0.378      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.28      |
# |    explained_variance   | 0.243      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.421      |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0284    |
# |    std                  | 0.73       |
# |    value_loss           | 1.67       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 34         |
# |    time_elapsed         | 6346       |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.06414789 |
# |    clip_fraction        | 0.412      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.25      |
# |    explained_variance   | 0.8        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.487      |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0359    |
# |    std                  | 0.72       |
# |    value_loss           | 1.56       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 35         |
# |    time_elapsed         | 6538       |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.07247101 |
# |    clip_fraction        | 0.426      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.22      |
# |    explained_variance   | 0.373      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.251      |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0209    |
# |    std                  | 0.715      |
# |    value_loss           | 2.04       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 36          |
# |    time_elapsed         | 6724        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.067873016 |
# |    clip_fraction        | 0.438       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.241       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.712       |
# |    value_loss           | 2.56        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 37          |
# |    time_elapsed         | 6913        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.056577727 |
# |    clip_fraction        | 0.411       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.489       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0251     |
# |    std                  | 0.707       |
# |    value_loss           | 2.96        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 38         |
# |    time_elapsed         | 7092       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.05442956 |
# |    clip_fraction        | 0.407      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.15      |
# |    explained_variance   | 0.905      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.525      |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.017     |
# |    std                  | 0.699      |
# |    value_loss           | 2.49       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 39         |
# |    time_elapsed         | 7284       |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.05975063 |
# |    clip_fraction        | 0.429      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.12      |
# |    explained_variance   | 0.626      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.507      |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0187    |
# |    std                  | 0.693      |
# |    value_loss           | 3.51       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 40         |
# |    time_elapsed         | 7464       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.06267088 |
# |    clip_fraction        | 0.463      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.11      |
# |    explained_variance   | 0.823      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.935      |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.00624   |
# |    std                  | 0.694      |
# |    value_loss           | 6.13       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 41          |
# |    time_elapsed         | 7657        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.078214034 |
# |    clip_fraction        | 0.467       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.896       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00774    |
# |    std                  | 0.691       |
# |    value_loss           | 7.15        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 42         |
# |    time_elapsed         | 7838       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.07519973 |
# |    clip_fraction        | 0.454      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.09      |
# |    explained_variance   | 0.901      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.558      |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0148    |
# |    std                  | 0.685      |
# |    value_loss           | 4.24       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 43         |
# |    time_elapsed         | 8011       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.07878667 |
# |    clip_fraction        | 0.47       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.06      |
# |    explained_variance   | 0.34       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.771      |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.00454   |
# |    std                  | 0.679      |
# |    value_loss           | 3.18       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 44         |
# |    time_elapsed         | 8183       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.07252472 |
# |    clip_fraction        | 0.485      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.05      |
# |    explained_variance   | 0.814      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.574      |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.00816   |
# |    std                  | 0.682      |
# |    value_loss           | 3.21       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 45         |
# |    time_elapsed         | 8354       |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.07987053 |
# |    clip_fraction        | 0.456      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.05      |
# |    explained_variance   | 0.768      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.02       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00748   |
# |    std                  | 0.682      |
# |    value_loss           | 5.52       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 46         |
# |    time_elapsed         | 8521       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.10876869 |
# |    clip_fraction        | 0.533      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.05      |
# |    explained_variance   | 0.866      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.24       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | 0.0129     |
# |    std                  | 0.683      |
# |    value_loss           | 7.96       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 47         |
# |    time_elapsed         | 8691       |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.08402451 |
# |    clip_fraction        | 0.507      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.04      |
# |    explained_variance   | 0.682      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.98       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | 0.0119     |
# |    std                  | 0.68       |
# |    value_loss           | 17.1       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 48         |
# |    time_elapsed         | 8859       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.11340721 |
# |    clip_fraction        | 0.592      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.04      |
# |    explained_variance   | 0.786      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.31       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | 0.018      |
# |    std                  | 0.68       |
# |    value_loss           | 9.68       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 49         |
# |    time_elapsed         | 9029       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.12155135 |
# |    clip_fraction        | 0.537      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.04      |
# |    explained_variance   | 0.852      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.78       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | 0.0129     |
# |    std                  | 0.679      |
# |    value_loss           | 10.1       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 50         |
# |    time_elapsed         | 9206       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.12352973 |
# |    clip_fraction        | 0.544      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.03      |
# |    explained_variance   | 0.845      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.04       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | 0.00532    |
# |    std                  | 0.677      |
# |    value_loss           | 8.43       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 51         |
# |    time_elapsed         | 9376       |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.08173985 |
# |    clip_fraction        | 0.535      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.03      |
# |    explained_variance   | 0.717      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.37       |
# |    n_updates            | 500        |
# |    policy_gradient_loss | 0.0111     |
# |    std                  | 0.676      |
# |    value_loss           | 11.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 52         |
# |    time_elapsed         | 9547       |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.09327005 |
# |    clip_fraction        | 0.491      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.02      |
# |    explained_variance   | 0.777      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.22       |
# |    n_updates            | 510        |
# |    policy_gradient_loss | 4.86e-06   |
# |    std                  | 0.674      |
# |    value_loss           | 13.1       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 53         |
# |    time_elapsed         | 9730       |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.13427877 |
# |    clip_fraction        | 0.583      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.01      |
# |    explained_variance   | 0.767      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.1        |
# |    n_updates            | 520        |
# |    policy_gradient_loss | 0.0327     |
# |    std                  | 0.669      |
# |    value_loss           | 8.57       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 54         |
# |    time_elapsed         | 9898       |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.08628105 |
# |    clip_fraction        | 0.525      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.99      |
# |    explained_variance   | 0.778      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.59       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | 0.0209     |
# |    std                  | 0.669      |
# |    value_loss           | 7.95       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 55          |
# |    time_elapsed         | 10066       |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.121229395 |
# |    clip_fraction        | 0.603       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.19        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.0481      |
# |    std                  | 0.674       |
# |    value_loss           | 6.08        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 56         |
# |    time_elapsed         | 10235      |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.25361207 |
# |    clip_fraction        | 0.553      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.02      |
# |    explained_variance   | 0.865      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.37       |
# |    n_updates            | 550        |
# |    policy_gradient_loss | 0.0272     |
# |    std                  | 0.683      |
# |    value_loss           | 5.41       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 57          |
# |    time_elapsed         | 10399       |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.101215065 |
# |    clip_fraction        | 0.505       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.12        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | 0.00819     |
# |    std                  | 0.681       |
# |    value_loss           | 4.97        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 58         |
# |    time_elapsed         | 10580      |
# |    total_timesteps      | 118784     |
# | train/                  |            |
# |    approx_kl            | 0.10720549 |
# |    clip_fraction        | 0.546      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.04      |
# |    explained_variance   | 0.834      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.13       |
# |    n_updates            | 570        |
# |    policy_gradient_loss | 0.0202     |
# |    std                  | 0.684      |
# |    value_loss           | 12.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 59         |
# |    time_elapsed         | 10743      |
# |    total_timesteps      | 120832     |
# | train/                  |            |
# |    approx_kl            | 0.14053506 |
# |    clip_fraction        | 0.499      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.04      |
# |    explained_variance   | 0.858      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.956      |
# |    n_updates            | 580        |
# |    policy_gradient_loss | 0.0122     |
# |    std                  | 0.682      |
# |    value_loss           | 9.84       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 60         |
# |    time_elapsed         | 10911      |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.12885544 |
# |    clip_fraction        | 0.592      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.02      |
# |    explained_variance   | 0.687      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.86       |
# |    n_updates            | 590        |
# |    policy_gradient_loss | 0.0328     |
# |    std                  | 0.678      |
# |    value_loss           | 5.44       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 61         |
# |    time_elapsed         | 11082      |
# |    total_timesteps      | 124928     |
# | train/                  |            |
# |    approx_kl            | 0.07075419 |
# |    clip_fraction        | 0.477      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.01      |
# |    explained_variance   | 0.793      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.432      |
# |    n_updates            | 600        |
# |    policy_gradient_loss | 0.00287    |
# |    std                  | 0.677      |
# |    value_loss           | 4.86       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 62          |
# |    time_elapsed         | 11250       |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.070234865 |
# |    clip_fraction        | 0.521       |
# |    clip_range           | 0.2         |
# ...
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.19      |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.842      |
# |    n_updates            | 1260       |
# |    policy_gradient_loss | 0.0206     |
# |    std                  | 0.72       |
# |    value_loss           | 10.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 128        |
# |    time_elapsed         | 21892      |
# |    total_timesteps      | 262144     |
# | train/                  |            |
# |    approx_kl            | 0.17678475 |
# |    clip_fraction        | 0.594      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.18      |
# |    explained_variance   | 0.693      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.5        |
# |    n_updates            | 1270       |
# |    policy_gradient_loss | 0.0283     |
# |    std                  | 0.715      |
# |    value_loss           | 11.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 129         |
# |    time_elapsed         | 22051       |
# |    total_timesteps      | 264192      |
# | train/                  |             |
# |    approx_kl            | 0.124542855 |
# |    clip_fraction        | 0.571       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.17       |
# |    explained_variance   | 0.775       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.988       |
# |    n_updates            | 1280        |
# |    policy_gradient_loss | 0.0292      |
# |    std                  | 0.718       |
# |    value_loss           | 8.92        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 130        |
# |    time_elapsed         | 22209      |
# |    total_timesteps      | 266240     |
# | train/                  |            |
# |    approx_kl            | 0.14427704 |
# |    clip_fraction        | 0.566      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.19      |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.4        |
# |    n_updates            | 1290       |
# |    policy_gradient_loss | 0.027      |
# |    std                  | 0.725      |
# |    value_loss           | 7.88       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 131        |
# |    time_elapsed         | 22374      |
# |    total_timesteps      | 268288     |
# | train/                  |            |
# |    approx_kl            | 0.15777558 |
# |    clip_fraction        | 0.554      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.917      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.02       |
# |    n_updates            | 1300       |
# |    policy_gradient_loss | 0.0133     |
# |    std                  | 0.727      |
# |    value_loss           | 9.36       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 11        |
# |    iterations           | 132       |
# |    time_elapsed         | 22530     |
# |    total_timesteps      | 270336    |
# | train/                  |           |
# |    approx_kl            | 0.1670851 |
# |    clip_fraction        | 0.6       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.21     |
# |    explained_variance   | 0.859     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.963     |
# |    n_updates            | 1310      |
# |    policy_gradient_loss | 0.0466    |
# |    std                  | 0.73      |
# |    value_loss           | 10.1      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 133        |
# |    time_elapsed         | 22690      |
# |    total_timesteps      | 272384     |
# | train/                  |            |
# |    approx_kl            | 0.13490927 |
# |    clip_fraction        | 0.576      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.833      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.53       |
# |    n_updates            | 1320       |
# |    policy_gradient_loss | 0.0411     |
# |    std                  | 0.726      |
# |    value_loss           | 7.9        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 134         |
# |    time_elapsed         | 22849       |
# |    total_timesteps      | 274432      |
# | train/                  |             |
# |    approx_kl            | 0.111879185 |
# |    clip_fraction        | 0.551       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.428       |
# |    n_updates            | 1330        |
# |    policy_gradient_loss | 0.0209      |
# |    std                  | 0.723       |
# |    value_loss           | 5.85        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 135        |
# |    time_elapsed         | 23011      |
# |    total_timesteps      | 276480     |
# | train/                  |            |
# |    approx_kl            | 0.11976804 |
# |    clip_fraction        | 0.585      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.18      |
# |    explained_variance   | 0.901      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.62       |
# |    n_updates            | 1340       |
# |    policy_gradient_loss | 0.0163     |
# |    std                  | 0.722      |
# |    value_loss           | 9.64       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 136        |
# |    time_elapsed         | 23172      |
# |    total_timesteps      | 278528     |
# | train/                  |            |
# |    approx_kl            | 0.13279235 |
# |    clip_fraction        | 0.498      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.17      |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.335      |
# |    n_updates            | 1350       |
# |    policy_gradient_loss | 0.00405    |
# |    std                  | 0.718      |
# |    value_loss           | 5.74       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 137        |
# |    time_elapsed         | 23332      |
# |    total_timesteps      | 280576     |
# | train/                  |            |
# |    approx_kl            | 0.12786962 |
# |    clip_fraction        | 0.584      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.15      |
# |    explained_variance   | 0.922      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.759      |
# |    n_updates            | 1360       |
# |    policy_gradient_loss | 0.0223     |
# |    std                  | 0.715      |
# |    value_loss           | 10.9       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 138        |
# |    time_elapsed         | 23493      |
# |    total_timesteps      | 282624     |
# | train/                  |            |
# |    approx_kl            | 0.13172755 |
# |    clip_fraction        | 0.541      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.14      |
# |    explained_variance   | 0.927      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.862      |
# |    n_updates            | 1370       |
# |    policy_gradient_loss | 0.00436    |
# |    std                  | 0.715      |
# |    value_loss           | 10.2       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 139        |
# |    time_elapsed         | 23646      |
# |    total_timesteps      | 284672     |
# | train/                  |            |
# |    approx_kl            | 0.50781316 |
# |    clip_fraction        | 0.598      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.14      |
# |    explained_variance   | 0.867      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.31       |
# |    n_updates            | 1380       |
# |    policy_gradient_loss | 0.0137     |
# |    std                  | 0.717      |
# |    value_loss           | 22.5       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 140        |
# |    time_elapsed         | 23812      |
# |    total_timesteps      | 286720     |
# | train/                  |            |
# |    approx_kl            | 0.16528513 |
# |    clip_fraction        | 0.603      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.15      |
# |    explained_variance   | 0.925      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.73       |
# |    n_updates            | 1390       |
# |    policy_gradient_loss | 0.0339     |
# |    std                  | 0.716      |
# |    value_loss           | 15         |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 141        |
# |    time_elapsed         | 23965      |
# |    total_timesteps      | 288768     |
# | train/                  |            |
# |    approx_kl            | 0.18135983 |
# |    clip_fraction        | 0.562      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.15      |
# |    explained_variance   | 0.919      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.08       |
# |    n_updates            | 1400       |
# |    policy_gradient_loss | 0.0129     |
# |    std                  | 0.718      |
# |    value_loss           | 11.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 142        |
# |    time_elapsed         | 24127      |
# |    total_timesteps      | 290816     |
# | train/                  |            |
# |    approx_kl            | 0.20858097 |
# |    clip_fraction        | 0.649      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.16      |
# |    explained_variance   | 0.93       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.46       |
# |    n_updates            | 1410       |
# |    policy_gradient_loss | 0.0367     |
# |    std                  | 0.722      |
# |    value_loss           | 13.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 143        |
# |    time_elapsed         | 24286      |
# |    total_timesteps      | 292864     |
# | train/                  |            |
# |    approx_kl            | 0.11465146 |
# |    clip_fraction        | 0.534      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.18      |
# |    explained_variance   | 0.944      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.02       |
# |    n_updates            | 1420       |
# |    policy_gradient_loss | 0.0146     |
# |    std                  | 0.725      |
# |    value_loss           | 10.2       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 144        |
# |    time_elapsed         | 24443      |
# |    total_timesteps      | 294912     |
# | train/                  |            |
# |    approx_kl            | 0.19226384 |
# |    clip_fraction        | 0.576      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.18      |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.659      |
# |    n_updates            | 1430       |
# |    policy_gradient_loss | 0.00979    |
# |    std                  | 0.727      |
# |    value_loss           | 9.91       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 145       |
# |    time_elapsed         | 24602     |
# |    total_timesteps      | 296960    |
# | train/                  |           |
# |    approx_kl            | 0.1312215 |
# |    clip_fraction        | 0.473     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.2      |
# |    explained_variance   | 0.965     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.471     |
# |    n_updates            | 1440      |
# |    policy_gradient_loss | 0.0234    |
# |    std                  | 0.734     |
# |    value_loss           | 6.77      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 146        |
# |    time_elapsed         | 24759      |
# |    total_timesteps      | 299008     |
# | train/                  |            |
# |    approx_kl            | 0.26058435 |
# |    clip_fraction        | 0.63       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.21      |
# |    explained_variance   | 0.932      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.03       |
# |    n_updates            | 1450       |
# |    policy_gradient_loss | 0.0232     |
# |    std                  | 0.73       |
# |    value_loss           | 16.1       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 147        |
# |    time_elapsed         | 24919      |
# |    total_timesteps      | 301056     |
# | train/                  |            |
# |    approx_kl            | 0.12692282 |
# |    clip_fraction        | 0.519      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.47       |
# |    n_updates            | 1460       |
# |    policy_gradient_loss | 0.0208     |
# |    std                  | 0.731      |
# |    value_loss           | 10.6       |
# ----------------------------------------

# %%
env.close()

# %%
PPO_path= os.path.join("Training","SaveModels","PPO_Model_CarRacing")

# %%
model.save(PPO_path)
# Out:
# C:\Users\shari\anaconda3\lib\site-packages\stable_baselines3\common\save_util.py:278: UserWarning: Path 'Training\SaveModels' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
del model

# %%
model= PPO.load(PPO_path,env=env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
env = gym.make(environment_name,render_mode="human")
env = DummyVecEnv([lambda: env])

# %%
evaluate_policy(model,env,n_eval_episodes=50, render=True)
# Out:
# (206.5012107847631, 148.2285415172549)

# %%
    env.close()

# %%
env = gym.make(environment_name,render_mode="human")
env = DummyVecEnv([lambda: env])

# %%
episodes=10
for episode in range(1, episodes+1):
    done=False
    obs= env.reset()
    score = 0
    
    while not done:
        env.render()
        action, _= model.predict(obs)
        obs, reward, done, info= env.step(action)
        score+=reward
    print("Episode: {} , Score: {}".format(episode,score))
# Out:
# Episode: 1 , Score: [221.93694]
# Episode: 2 , Score: [531.91724]
# Episode: 3 , Score: [679.3173]
# Episode: 4 , Score: [257.5904]
# Episode: 5 , Score: [292.2212]
# Episode: 6 , Score: [631.4555]
# Episode: 7 , Score: [190.41457]
# Episode: 8 , Score: [637.86285]
# Episode: 9 , Score: [237.88121]
# Episode: 10 , Score: [597.60156]

# %%
env.close()
